# %% [markdown]
# <a href="https://colab.research.google.com/github/Adeline187/Build_and_Deploy-ML/blob/main/Expt-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #

# %%
import ipywidgets as widgets
from IPython.display import display

slider = widgets.IntSlider(
    value=50,
    min=0,
    max=100,
    step=1,
    description="Value:"
)

output = widgets.Output()

def on_value_change(change):
    output.clear_output()
    with output:
        print(f"Slider value is {change['new']}")

slider.observe(on_value_change, names="value")

display(slider, output)
# Out:
# IntSlider(value=50, description='Value:')
# Output()
